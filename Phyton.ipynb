# %%
anInteger = 3
anInteger/3
if type(anInteger) == "int":
    print("OK!")

# %%
aBoolean = True
type(aBoolean)
3 > 1 #True
1 > 2 #False
# Out:
# False

# %%
##LISTAS: son listas mutables definidas entre corchetes

lista = []
lista #devolvera []

lista.append(23) #lo añaderá al final
lista #devolvera [23]

lista += ["the", 32]
lista #devolvera [23, 'the', 32]

len(lista) #devolvera 3

lista = [3,-2,45,99,4]
lista[0] #devolvera 3

lista[:] #devolvera toda la lista: [3, -2, 45, 99, 4]

lista[2:] #devolvera desde la posición 2: [45, 99, 4]

lista[2:4] #devolvera desde la posición 2 a la 4: [45, 99]

lista.index(-2) #busca la posición dentro de la lista: 1

lista.remove(-2) #eliminar esa valor de la lista
#otro metodo de eliminar
eliminado = lista.pop(-2) #elimina el penultimo elemento
eliminado #devolverá 99
lista #devolverá [3, 45, 4]

sorted (lista) #ordenará siempre y cuando sea todo int, o texto
sorted (lista, reverse=True) #ordenar al revés
# Out:
# [45, 4, 3]

# %%
##TUPLAS: listas NO mutables, definidas entre parentesis

tupla =(3,2,"hola", [], "hola")
tupla.count("hola") #devolverá 2

#tupla += 1 #devolverá error, no se puede modificar una tupla

tupla[3].append("Adios") #esto si es permitido porque el elemento de posicion 3 de la tupla es una lista
tupla #devolverá (3, 2, 'hola', ['Adios'], 'hola')
# Out:
# (3, 2, 'hola', ['Adios'], 'hola')

# %%
##DICCIONARIOS: definidos entre llaves {} separa elementos con :

dicc = {"nombre":"Sergio", "llave":"25"}
dicc["llave"] #devuelve 25

#dicc["NOMBRE"] #devuelve error, es casesensitive

dicc.keys() #devuelve todas las llaves: dict_keys(['nombre', 'llave'])
dicc.values() #devuelve todos los valores: dict_values(['Sergio', '25'])

len(dicc) #devuelve 2

del dicc["nombre"]
dicc #devuelve {'llave': '25'}
# Out:
# {'llave': '25'}

# %%
##STRINGS, CADENAS

cadena = "Test \t \n \" "
cadena #devuelve 'Test \t \n " '
#print(cadena) #devuelve Test tabula, salto de carro y "

cadena = "mi variable string %s" % ("CADENA")
cadena #devuelve 'mi variable string CADENA'

cadena = "mi variable float %f" % (3)
cadena #devuelve 'mi variable float 3.000000'

cadena = "mi texto"
cadena[4] #'e'
cadena[1:3] #'i '

#cadena.capitalize() #'Mi texto'
#cadena.upper() #'MI TEXTO'

cadena.replace("texto", "XXX") #buscara texto y lo remplazará por XXX
cadena

cadena.split(" ") #transforma una cadena en lista con el patron usado de parametro en este caso un espacio
cadena #devolvera ["mi", "texto"]

cadena.index("texto") #devuelve la posición dentro de la lista en este caso 1
# Out:
# 3

# %%
##TIPS Jupyter

# var = "cadena"
# ?var.strip #devuelve la ayuda de esa funcion

# Ctrl + Enter para ejecutar

# %%
##OPERADORES LOGICOS

x = 50
x == 49 #False
x !=49 #True

x = "22"
int(x) == 22 #Convertivo x a int y la comparacion es valida
# Out:
# True

# %%
##IF

x=6
if x > 20:
    print("OK")
elif x / 3 == 2:
    print("x es 6")
elif type(x) == str:
    print("x es una cadena")
else:
    print("NOT OK")
# Out:
# x es 6

# %%
##TRY EXCEPT

#ejemplo1
try:
    3/0
    print("lo hizo")
except Exception as ex:
    print("excepcion: %s" % ex)
    

#ejemplo2
lista = [1,2,3,4]
a = "XXX"
try:
    if (5 not in lista) and (a =="XXX"):
        3*0
        print("lo hizo")
except ZeroDivisionError as ex:
    print("Error: %s" % ex)
except ArithmeticError as ex:
    print("Error: %s" % ex)
finally:
    print("termine")
# Out:
# excepcion: division by zero
# lo hizo
# termine

# %%
##ADVANCED LOGIC

x = ["Casa", 3, 22]
y= 12
z = "Coche"

if (2 in x) or (y > x[1]):
    print("cumple una condicion")
else:
    print("NO las cumple")
# Out:
# cumple una condicion

# %%
##PROBLEMA IMPUT

x = input("dame un numero: ")

try:
    x = int(x) #le convertimos a entero

    if x > 20:
        print("es mayor de 20")

    elif x % 2 == 1:
        print("es un numero impar y menor a 20")

    else:
        print ("Ni par ni mayor a 20, era: " + x)
    
except:
    print("no me diste un numero")
# Out:
# dame un numero: 15
# es un numero impar y menor a 20

# %%
##FOR LOOPS

#ejemplo1
lista = [4,13,25,41,78]
for i in lista:
    print(i)
    
#ejemplo2
cadena ="hola"
for c in cadena:
    print(c)

#ejemplo3
for orden_inv in sorted(lista, reverse=True): #ordenar una lista
    print(orden_inv)

#ejemplo4
dicc = {"nombre":"Sergio", "edad":41, "perfil":{}}
for a in dicc:
    print(a, dicc[a], type(dicc[a]))

#ejemplo5
dicc2 = {"hora1": 2, "hora2": 13, "hora3": 19}
for valor in dicc2.values():
    print(valor) #devuelve 2 13 19

#ejemplo6
for clave, valor in dicc2.items():
    print(clave, valor) #devuelve hora1 2 hora2 13 hora3 19
# Out:
# 4
# 13
# 25
# 41
# 78
# h
# o
# l
# a
# 78
# 41
# 25
# 13
# 4
# nombre Sergio <class 'str'>
# edad 41 <class 'int'>
# perfil {} <class 'dict'>
# 2
# 13
# 19
# hora1 2
# hora2 13
# hora3 19

# %%
##WHILE LOOPS

#ejemplo1
i = 0
while i < 10:
    print("looping")
    i += 1

#ejemplo2
i = 1
while (i<10) and (i%2==1):
    print("loop",i)
    i+=1
# Out:
# looping
# looping
# looping
# looping
# looping
# looping
# looping
# looping
# looping
# looping
# loop 1

# %%
##CONTINUE, BREAK, PASS

#ejemplo1
lista1 = [1,3,5,7,9,12,23]
for index, data in enumerate(lista1): #funcion enumerate
    print(index, data)

lista2 = [9,8,7,6]
for d1, d2 in zip(lista1, lista2): #funcion zip
    print(d1,d2)
    

for i in lista1[:2]: #imprime los dos primeros elementos de lista1
    print(i)
    

#ejemplo2
dicc ={"nombre":"sergio", "edad":"41"}
for valor in dicc.values():
    if valor == "sergio":
        print("Soy yo")
        continue #probar con break y pass para ver que hace
#         break
#         pass
    print(valor)
# Out:
# 0 1
# 1 3
# 2 5
# 3 7
# 4 9
# 5 12
# 6 23
# 1 9
# 3 8
# 5 7
# 7 6
# 1
# 3
# Soy yo
# 41

# %%
##PROBLEMA ROMBO
ancho = 5
for i in range(ancho):
    #print("i=",i)
    print(''*(ancho-i-1)+'$'*(i+1))
for j in range(ancho-1,0,-1):
    #print("j=",j)
    print(''*(ancho-j)+'$'*(j))
# Out:
# $
# $$
# $$$
# $$$$
# $$$$$
# $$$$
# $$$
# $$
# $

# %%
##PROBLEMA ADIVINA EL NUMERO
import random
numero = random.randint(1,10) #elegimos un aleatorio de 1 a 10
respuesta = 0
intento = 0
while(respuesta != numero):
        respuesta = int(input("dime un numero "))
        intento+=1
        if (respuesta == numero):
            print("Has encontrado el numero en el intento: %s" % intento)
            break
        continue
# Out:
# dime un numero 4
# dime un numero 5
# dime un numero 6
# dime un numero 7
# dime un numero 8
# dime un numero 9
# dime un numero 1
# dime un numero 2
# dime un numero 3
# dime un numero 10
# Has encontrado el numero en el intento: 10

# %%
##FUNCIONES

#ejemplo1
def funcion1(param1):
    if type(param1) in [int, float]:
        print("es entero o float")
        
x = funcion1("a")
y = funcion1(4.0)

#ejemplo2 - funcion con dos parametros y con return
def suma(x,y):
    return x+y

suma(2,3)
# Out:
# es entero o float
# 5

# %%
## *args y **kwargs

#ejemplo1 con *args, aceptará un numero indefinido de parametros y crea una lista con ellos
def funcion1(*args):
    for arg in args:
        print(type(arg))

funcion1(1,"casa",4.0)

#ejemplo2 *args y un parametro de inicio
def funcion2(param1, param2, *args): #que se salte los dos primeros parametros
    for arg in args:
        print(type(arg)) #devolverá <class 'float'>

funcion2(1,"casa",4.0)

#ejemplo3 con **kwargs, aceptará un numero indefinido de parametros y crea un diccionario con ellos
def funcion3(**kwargs):
    print(kwargs) #devuelve {'x': 1, 'y': 3, 'z': 7}

funcion3(x=1, y=3, z=7)

#ejemplo4 con **kwargs, que se salte los dos primeros parametros
def funcion4(p1,p2,**kwargs):
    print(kwargs) #devuelve {'x': 2, 'y': 3, 'z': 4}

funcion4(1, "casa", x=2, y=3, z=4)

#ejemplo5 *args y **kwargs juntos
def funcion5(*args,**kwargs):
    print(args,kwargs) #devuelve una lista y un diccionario (2, 'coche', -4) {'x': 3, 'y': 4, 'z': 5}

funcion5(2, "coche", -4, x=3, y=4, z=5)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# {'x': 1, 'y': 3, 'z': 7}
# {'x': 2, 'y': 3, 'z': 4}
# (2, 'coche', -4) {'x': 3, 'y': 4, 'z': 5}

# %%
##CLASES (objetos que almacenan funciones y atributos)

#ejemplo1
class clase1():
    test = 69
    def add10(self, p1): #https://pythontips.com/2013/08/07/the-self-variable-in-python-explained/
        #p1 será una variable local a la función
        self.p1 = p1
        if type(self.p1) != int:
            print("no es entero")
        else:
            print("es entero, le sumo 10")
            return p1 + 10

a = clase1()
a.add10(3) #devolvera 13
#a.add10() #devolvera error porque falta el parametro
a.test #devolvera 69

#ejemplo2 cargar clases desde archivos
# from nombre_fichero import clase2 #habra un fichero llamado nombre_fichero.py en el mismo directorio q este archivo de Jupyter
# nombre_fichero.funcion()
# Out:
# es entero, le sumo 10
# 69

# %%
##PROBLEMA

texto = "en un lugar de la mancha de cuyo nombre no quiero acordarme"

class parseador_lenguaje(object):
    def contar_palabras(self, document, **kwargs):
        self.document = document
        listaPalabras = {}
        if kwargs["raw"] == True:
            palabrasSplit = document.split(" ") #lo separams en palabras
        for palabra in palabrasSplit:
            if palabra not in listaPalabras:
                listaPalabras[palabra] = 0
            listaPalabras[palabra] +=1
            
        return listaPalabras
    
    def contar_letras_diferentes(self, document, raw):
        self.document = document
        self.raw = raw
        diccLetras = {}
        if (type(self.raw) == bool) and (self.raw is not True):
            self.document = " ".join(self.document)
        elif type(self.raw) != bool:
            raise TypeError("Debe ser verdadero o falso")
        else:
            pass
        
        document = document.replace(" ","").lower()
        for caracter in document:
            if caracter not in diccLetras:
                diccLetras[caracter] = 0
            diccLetras[caracter] +=1
            
        return diccLetras
    
    def eliminar_palabra(self, texto, *args):
        stopWords = args
        if type(texto) != list:
            texto = texto.split(" ")
        removedWords = [word for word in texto if word.lower() not in stopWords]
        
        return removedWords

a = parseador_lenguaje()

#dejar descomentada una de estas 3 líneas para ejecutar una de las funciones
#a.contar_palabras(texto, raw=True)
#a.contar_letras_diferentes(texto, True)
a.eliminar_palabra(texto, "lugar", "mancha")
# Out:
# ['en', 'un', 'de', 'la', 'de', 'cuyo', 'nombre', 'no', 'quiero', 'acordarme']

# %%
##PROBLEMA procesar datos de un .csv

#columnas del archivo .csv
# page_id
# name
# urlslug
# ID
# ALIGN
# EYE
# HAIR
# SEX
# GSM
# ALIVE
# APPEARANCES
# FIRST APPEARANCE
# Year

import csv
totalApariciones = {}
vivosDict = {}

with open('marvel-wikia-data.csv') as csv_file:
    reader = csv.reader(csv_file, delimiter=',')
    contador_lineas = 0
    for row in reader: #recorremos las rows
        nombre = row[1].split("(")[0].rstrip() #los nombres son Spider-Man (Peter Parker), asi quitamos lo que haya tras encontrar un parentesis
        vivoomuerto = row[9]
        mundo = row[1][row[1].find("(")+1:row[1].find(")")]
        try:
            aparecido = int(row[10])
        except:
            continue
        if vivoomuerto == "Living Characters":
            if mundo not in vivosDict:
                vivosDict[mundo] = []
            if mundo not in totalApariciones:
                totalApariciones[mundo] = 0
                
            vivosDict[mundo].append(nombre)
            totalApariciones[mundo] += int(aparecido) 
            
        contador_lineas +=1
        
print(f'He leido {contador_lineas} lineas.')
print("Lista de personajes vivos: ",vivosDict)
print("\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
print("Apariciones de cada personaje: ",totalApariciones)
# Out:
# He leido 15280 lineas.
# Lista de personajes vivos:  {'Peter Parker': ['Spider-Man'], 'Steven Rogers': ['Captain America'], 'James \\"Logan\\" Howlett': ['Wolverine'], 'Anthony \\"Tony\\" Stark': ['Iron Man'], 'Thor Odinson': ['Thor'], 'Earth-616': ['Benjamin Grimm', 'Reed Richards', 'Scott Summers', 'Jonathan Storm', 'Henry McCoy', 'Susan Storm', 'Namor McKenzie', 'Ororo Munroe', 'Clinton Barton', 'Matthew Murdock', 'Stephen Strange', 'Mary Jane Watson', 'John Jonah Jameson', 'Robert Drake', 'Henry Pym', 'Warren Worthington III', 'Piotr Rasputin', 'Wanda Maximoff', 'Nicholas Fury', 'Janet van Dyne', 'Natalia Romanova', 'Kurt Wagner', 'Vision', 'May Reilly', 'Katherine Pryde', 'Carol Danvers', 'Jennifer Walters', 'Emma Frost', 'Frank Castle', 'Luke Cage', 'Conan', 'Joseph Robertson', 'Pietro Maximoff', 'Hercules', 'Victor von Doom', 'Max Eisenhardt', 'Elizabeth Braddock', 'Norrin Radd', 'Norman Osborn', 'Eugene Thompson', 'Simon Williams', 'Samuel Guthrie', 'James Buchanan Barnes', 'Remy LeBeau', 'Daniel Rand', 'Nathan Summers', 'Elizabeth Brant', 'Richard Jones', 'Edwin Jarvis', 'Alexander Summers', 'Patricia Walker', 'Loki Laufeyson', 'Franklin Nelson', 'Brian Braddock', 'James Rhodes', 'Crystalia Amaquelin', 'Samuel Wilson', 'Wilson Fisk', 'Odin Borson', 'Dane Whitman', 'Harold Osborn', 'Franklin Richards', 'Jessica Drew', 'Roberto da Costa', 'Rahne Sinclair', 'Elizabeth Ross', 'Lorna Dane', 'Johnathon Blaze', 'Sif', 'Jubilation Lee', 'Volstagg', 'Galactus', 'Danielle Moonstar', 'Marc Spector', 'Medusalith Amaquelin', 'Illyana Rasputina', 'Sean Cassidy', 'Thomas Raymond', 'Hogun', 'Raven Darkholme', 'Barbara Morse', 'Blackagar Boltagon', 'Brunnhilde', 'Alison Blaire', 'John Walker', 'Greer Grant', 'Karla Sofen', 'William Baker', 'Sharon Carter', 'Felicia Hardy', 'Cain Marko', 'Monica Rambeau', 'Maria Hill', 'Ben Urich', 'Heather Douglas', 'Millicent Collins', 'James Proudstar', 'Angelica Jones', 'Edward Brock', 'MacDonald Gargan', 'Mephisto', 'Tabitha Smith', 'Jean-Paul Beaubier', 'Daniel Ketch', 'Neena Thurman', 'Wong', 'Thanos', 'Shang-Chi', 'Alicia Masters', 'Robert Baldwin', 'Vance Astrovik', 'Wendell Vaughn', 'Chili Storm', 'Abner Jenkins', 'Elektra Natchios', 'Forge', 'Virginia Potts', 'Walter Langkowski', 'Gorgon', 'James Madrox', 'Heimdall', 'Theresa Cassidy', 'Laura Kinney', 'Arthur Douglas', 'Kevin Plunder', 'Melissa Gold', 'Lockheed', 'Mercedes Knight', 'Lockjaw', 'Adam Warlock', 'Heather McNeil', 'Curtis Connors', 'Theodore Sallis', 'Adrian Toomes', 'Amora', 'Clea', 'Eugene Judd', 'Daimon Hellstrom', 'John Jonah Jameson III', 'Triton', 'Meggan Puceanu', 'Robert Reynolds', 'Santo Vaccarro', 'Jonathan Clay', 'Sersi', 'Guido Carosella', 'Zabu', 'Michael Morbius', 'Julio Richter', 'Megan Gwynn', 'Kyle Richmond', 'Tyrone Johnson', 'Maxwell Dillon', 'Valerie Cooper', 'Anna May', 'Vlad Dracula', 'Tandy Bowen', 'Monet St. Croix', 'Gamora', 'Amara Aquilla', 'Julia Carpenter', 'Jane Foster', 'Mortimer Toynbee', 'Scott Lang', 'Paige Guthrie', 'Erik Josten', 'Jeanne-Marie Beaubier', 'Carl Creel', 'Gloria Grant', 'Michael Twoyoungmen', 'Hope Summers', 'Alexander Power', 'Jessica Jones', 'Frederick Dukes', 'Eric Brooks', 'Eros', 'Madison Jeffries', 'The Wizard', 'Akihiro', 'Jonothon Starsmore', 'Helmut Zemo', 'Victor Borkowski', 'Douglas Ramsey', 'Quentin Beck', 'Herbert Wyndham', 'Julian Keller', 'Jack Russell', 'Celeste Cuckoo', 'Valentina Allegra de Fontaine', 'Ophelia Sarkissian', 'Colleen Wing', 'Irma Cuckoo', 'Sebastian Shaw', 'Phoebe Cuckoo', 'Sage', 'Valeria Richards', 'Donald Blake', 'Henry Gyrich', 'Redwing', 'Christopher Powell', 'Harvey Elder', 'Dirk Garthwaite', 'Pip Gofern', 'Tony Masters', 'James Hudson', 'Miles Warren', 'Kallark', 'Shiro Yoshida', 'Elvin Haliday', 'James Bradley', 'Calvin Zabo', 'Frederick Myers', 'Mantis', 'Marlene Alraune', 'Rachel Leighton', 'Nathaniel Essex', 'Beta Ray Bill', 'Leech', 'Bug', 'Peter Petruski', 'Julie Power', 'Giuletta Nefaria', 'Maximus', 'Hisako Ichiki', 'Dmitri Smerdyakov', 'X-51', 'Madelyne Pryo ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Apariciones de cada personaje:  {'Peter Parker': 4043, 'Steven Rogers': 3360, 'James \\"Logan\\" Howlett': 3061, 'Anthony \\"Tony\\" Stark': 2961, 'Thor Odinson': 2258, 'Earth-616': 185455, 'Robert Bruce Banner': 2017, 'Anna Marie': 850, 'Android': 587, 'Wade Wilson': 500, 'Thaddeus Ross': 415, 'Victor Creed': 382, 'Symbiote': 549, 'Lester': 281, 'Technarch': 276, 'Thunderball': 146, 'Kaine': 137, 'Sarah': 119, 'Joseph': 168, 'Eternal': 152, 'Asgard': 113, 'Horse': 251, 'Vigilante': 84, 'Cosmic Being': 90, 'Evan Sabahnur': 78, 'Sybil': 70, 'Clone': 138, 'Moloid': 244, 'Siren': 61, 'Psychic Entity': 60, 'Vincent': 61, 'Lilin': 85, 'Clown': 55, 'William Burnside': 52, 'Morlock': 86, 'Imperial Guard': 115, 'Asgardian': 136, 'Althea': 44, 'Ragnarok': 42, 'Alien': 65, 'Davos': 39, 'Warbound': 39, 'Dog': 70, 'Ted Calloway': 36, 'Doppelganger': 86, 'Nijo': 35, 'Pantheon': 144, 'Blood': 34, 'Robot': 89, 'Demon': 85, 'Japheth': 31, 'Marauders': 30, 'Apache Chief': 29, 'Computer': 42, 'British Crimelord': 29, 'Zadkiel agent': 29, 'Robbie': 28, 'Hydra Agent': 28, 'Automaton': 27, 'Patrick': 27, 'Duplicate': 26, 'SHIELD': 25, 'Thief': 36, 'Destroyer': 25, 'Multiverse': 24, 'Devil-Hunter': 24, 'Nova Foe': 24, 'Deviant': 45, 'Dark Riders': 24, 'Sorcerer': 41, 'Ninja': 23, 'Well of All Things': 23, 'Evolved Tiger': 23, 'Tex Morgan': 22, 'Atlantean beast': 22, 'Lightbearer': 22, 'UCT': 22, 'son of Ruby': 41, 'Excalibur': 22, 'Strange': 22, 'LMD, Heroes Reborn': 22, 'Atlantean': 52, 'Deathwing': 21, 'Thunderiders': 21, 'Coconut Grove': 21, 'Skrull': 57, 'Heroes Reborn': 387, 'Outlaw Kid': 20, 'Counter-Earth': 45, 'Inferno Baby': 37, 'Peter': 20, 'Phantom Reporter': 19, 'Native American': 21, 'Entity': 33, 'Quentin Carnival': 19, 'LMD': 116, 'M.O.D.O.K. Superior': 19, 'Texas Kid': 35, 'Goddess': 22, 'Deity': 35, 'Intruders': 18, 'First Line': 20, 'Earth-5012': 18, 'Cheyenne': 17, 'Leader': 17, 'Mekkan': 17, 'Tsiln': 17, 'Legion Personality': 111, 'Olympian': 36, 'Whiplash': 16, 'NYPD': 60, 'Latverian': 15, 'Crazy Gang': 28, 'Lucian': 15, 'Godpack': 15, 'Nextwave': 15, 'Sara': 15, 'Kowalski': 15, 'Elementals': 49, 'Torpedo': 14, 'Warpies': 61, 'RCX agent': 14, 'Microverse': 26, 'Fortisquian': 14, 'Sentinel': 34, 'Earth-982': 25, 'Michael': 14, 'WWII': 17, 'Savage Land Mutate': 27, 'Cyborg': 15, 'Chaste': 19, 'Gabriel': 13, 'Nyx': 13, 'Savage Land': 14, 'Genoshan': 20, 'Anton': 13, 'Avenger': 13, 'Masked Raider': 19, 'Arrowhead': 12, 'Deviant Mutate': 12, 'Crime Boss': 12, 'Fallen Angels': 12, 'Hate-Monger': 12, 'Spinsterhood': 13, 'Hydra': 18, 'Pride': 21, 'Karl': 12, 'Sara Ehret': 12, 'Richard': 12, 'Lincoln': 11, 'New Man': 13, 'Mutant': 94, 'O-Bengh': 11, 'Digitek': 11, 'Midas': 11, 'Young Masters': 19, 'Cluster': 11, 'Goon': 10, 'Undying Ones Leader': 10, 'Crystalium': 10, 'Olympian Beast': 10, 'Jimmy': 10, 'Project Ultra-Tech': 10, 'Hellbent': 24, 'Creature': 11, 'Pathogen': 10, 'Herald': 10, 'Sisterhood of the Wasp': 10, 'A.I.M. Agent': 10, 'Grace': 10, 'Evil Deadpool': 10, 'Extraterrestrial': 11, 'Inhuman': 51, 'Statue': 10, 'Polemachus': 9, 'New Men': 12, 'Frost Giant': 10, 'Lobster': 9, 'Mitchell': 9, 'Avatars': 31, 'Crown': 9, 'Nina': 12, 'Humanoid': 9, 'Terrorist': 10, 'Major Mapleleaf': 9, 'Vagrant': 9, 'Cortex': 9, 'Red Right Hand': 9, 'Bor': 9, 'Nova': 10, 'Weinberg': 8, 'Ancient Atlantis': 8, 'Hindu Deity': 8, 'Sparrow': 8, 'Tremont': 8, 'Vegas Thirteen': 8, 'Chimpanzee': 8, 'Onslaught Reborn': 43, 'Fred': 8, 'Franklin': 8, 'Dark Reign': 8, 'Amanda': 8, 'Golden Age': 7, 'Donkey': 7, 'Shotgun City': 7, 'Dimension Z': 7, 'Furies': 18, 'San Francisco': 7, 'San Diego': 7, 'Blue Marvel': 7, 'Revolutionary War': 7, 'Corporation': 8, 'Geneticist': 7, 'Doctor': 10, 'Australian': 7, 'Laralie': 7, 'Clyde': 7, 'Titan': 7, 'O.Z. Chase': 7, 'New Warriors': 7, 'Mercenary': 17, 'Space Phantom': 17, 'Cell-12': 7, 'Punk Kid': 14, 'Mary': 7, 'Omega Core': 7, 'Daydream': 7, 'Angel': 33, 'Raptor': 10, 'Weapon XIII': 7, 'Two-Gun Kid': 7, 'Leopard Girl ...

# %%
##PROBLEMA adivinar numero

import random

cuantos_juegos = int(input("Cuantos juegos quieres "))
i=0

for i in range(cuantos_juegos):
    print("Comineza el juego número",i+1)
    numero = random.randint(1,5)
    respuesta = 0
    intento = 0
    while(respuesta != numero):
            respuesta = int(input("dime un numero "))
            intento+=1
            if(respuesta > numero):
                print("muy alto")
            elif(respuesta < numero):
                print("muy bajo")
            elif (respuesta == numero):
                print("Has encontrado el numero en el intento: %s" % intento)
            continue
    i+=1
# Out:
# Cuantos juegos quieres 1
# Comineza el juego número 1
# dime un numero 1
# Has encontrado el numero en el intento: 1

# %% [markdown]
# #
